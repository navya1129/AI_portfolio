# %% [markdown]
# <a href="https://colab.research.google.com/github/navya1129/AI_portfolio/blob/main/Day1SetUp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progressive skills needed to build and deploy AI systems, from foundational technical abilities to strategic business impact:
#
# *   **Foundational Technical Skills (Data & Algorithms):** Covers the base layers of data collection, cleaning, management, and the understanding/implementation of core AI/ML algorithms.
# *   **AI Engineering & Optimization:** Focuses on optimizing model performance, efficiency, scalability, and the engineering practices (like MLOps) needed for robust deployment.
# *   **Domain Application & Integration:** Involves applying AI solutions to specific real-world problems, integrating them into existing systems or products, and understanding the user experience.
# *   **Strategic Vision & Business Acumen:** The apex layer, encompassing the ability to identify business value, manage ethical considerations, strategize AI adoption, and measure overall impact.
